# %%
from ChargingCaseLib import ChargingCaseLib

cc = ChargingCaseLib()
cc.connect_charging_case()
# Out:
# ChargingCase InitedBluetooth Inited
#
# Blue Connect Case...
# Connect To /org/bluez/hci1/dev_D0_14_11_20_20_18
# Discovering Device
# Press Reset Let Device Discovable!!!
# founded
# Get Connection State
# do connecting...
# dev info:
# Name:  Echo
# Address:  D0:14:11:20:20:18
# Paired:  0
# Connected:  1
# Blue Discovering Char...
# Discovering service and characteristic...
# Case Char Interface <Interface <ProxyObject wrapping <dbus._dbus.SystemBus (system) at 0x7fadd85ee0> :1.9 /org/bluez/hci1/dev_D0_14_11_20_20_18/service0019/char001a at 0x7f8f4a2740> implementing 'org.bluez.GattCharacteristic1' at 0x7f8ee63d30>

# %%
cc.case_open()
# Out:
# Send To Case
# WriteValue: bytearray(b'\t\x00\x03\x00\x00')

# %%
cc.press_button("Fn", "Long")
# Out:
# Send To Case
# WriteValue: bytearray(b'\t\x00\x07\x00\x00\x02')

# %%
cc.case_close()

# %%
# !pactl info
# Out:
# Server String: /run/user/1000/pulse/native
# Library Protocol Version: 34
# Server Protocol Version: 34
# Is Local: yes
# Client Index: 41
# Tile Size: 65472
# User Name: firmware
# Host Name: rpi
# Server Name: pulseaudio
# Server Version: 14.2
# Default Sample Specification: s16le 2ch 44100Hz
# Default Channel Map: front-left,front-right
# Default Sink: alsa_output.platform-bcm2835_audio.analog-stereo
# Default Source: alsa_output.platform-bcm2835_audio.analog-stereo.monitor
# Cookie: 49a1:3317

# %%
# !pactl list
# Out:
# Module #0
# 	Name: module-device-restore
# 	Argument:
# 	Usage counter: n/a
# 	Properties:
# 		module.author = "Lennart Poettering"
# 		module.description = "Automatically restore the volume/mute state of devices"
# 		module.version = "14.2"
#
# Module #1
# 	Name: module-stream-restore
# 	Argument: restore_device=false
# 	Usage counter: n/a
# 	Properties:
# 		module.author = "Lennart Poettering"
# 		module.description = "Automatically restore the volume/mute/device state of streams"
# 		module.version = "14.2"
#
# Module #2
# 	Name: module-card-restore
# 	Argument:
# 	Usage counter: n/a
# 	Properties:
# 		module.author = "Lennart Poettering"
# 		module.description = "Automatically restore profile of cards"
# 		module.version = "14.2"
#
# Module #3
# 	Name: module-augment-properties
# 	Argument:
# 	Usage counter: n/a
# 	Properties:
# 		module.author = "Lennart Poettering"
# 		module.description = "Augment the property sets of streams with additional static information"
# ...

# %%
# !bluetoothctl disconnect
# Out:
# Missing device address argument

# %%
# !bluetoothctl connect 12:34:56:78:a0:b3
# Out:
# Attempting to connect to 12:34:56:78:a0:b3
# [CHG] Device 12:34:56:78:A0:B3 Connected: yes
# Failed to connect: org.bluez.Error.Failed
